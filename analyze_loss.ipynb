# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/giacomo/Desktop/results_cl_ssl/OCL/resnet9/hypertune_iid_long_rn18wide_no_strategy_simsiam_05-18_14-16/iid_no_strategy_simsiam_cifar100_05-18_14-16/pretr_loss.csv')
df.head()
# Out:
#        loss  exp_idx  epoch  mb_idx  mb_pass
# 0  0.003294        0      0       0        0
# 1 -0.004181        0      0       1        0
# 2 -0.015610        0      0       2        0
# 3 -0.039684        0      0       3        0
# 4 -0.030146        0      0       4        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27141 entries, 0 to 27140
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   loss     27141 non-null  float64
#  1   exp_idx  27141 non-null  int64
#  2   epoch    27141 non-null  int64
#  3   mb_idx   27141 non-null  int64
#  4   mb_pass  27141 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 1.0 MB

# %%
loss_list = df['loss'].to_list()
print(loss_list)
# Out:
# [0.0032940316013991, -0.0041808215901255, -0.0156102068722248, -0.039683673530817, -0.0301462989300489, -0.0480623543262481, -0.0395967662334442, -0.0799433141946792, -0.0844406858086586, -0.1017581224441528, -0.1060078144073486, -0.1285238713026046, -0.1446231305599212, -0.1796988397836685, -0.1667651534080505, -0.1730165928602218, -0.1765773594379425, -0.2450642585754394, -0.2554203569889068, -0.274860680103302, -0.2572044730186462, -0.2768428921699524, -0.3116156756877899, -0.2955609261989593, -0.3422281146049499, -0.2919238805770874, -0.3810801208019256, -0.3706128597259521, -0.3597586154937744, -0.3718548119068146, -0.4094056487083435, -0.4140077531337738, -0.3639422357082367, -0.4275409579277038, -0.4297035932540893, -0.4341879487037658, -0.4344322085380554, -0.4332740008831024, -0.4529028534889221, -0.4639778137207031, -0.412663459777832, -0.4640229344367981, -0.432672381401062, -0.4903416931629181, -0.475716233253479, -0.4785987734794616, -0.4368534088134765, -0.4572762846946
# ...

# %%
plt.figure(figsize=(14, 6))

plt.plot(loss_list)
plt.show()

# %%
def moving_average(data, window_size):
    from collections import deque
    window = deque(maxlen=window_size)
    smoothed = []

    for i in range(len(data)):
        window.append(data[i])
        if len(window) == window_size:
            smoothed.append(sum(window) / window_size)

    return smoothed

# %%
#smooth the array with average
smooth_loss = moving_average(loss_list, 6)

# %%
plt.figure(figsize=(14, 6))
plt.plot(smooth_loss)
plt.show()
