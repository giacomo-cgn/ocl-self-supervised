# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/no_strategy_simsiam_cifar100_11-20_18-37/pretr_loss.csv')
df.head()
# Out:
#        loss  exp_idx  epoch  mb_idx  mb_pass
# 0  0.000223        0      0       0        0
# 1  0.000736        0      0       0        1
# 2 -0.001858        0      0       0        2
# 3 -0.002509        0      0       1        0
# 4 -0.003084        0      0       1        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4740 entries, 0 to 4739
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   loss     4740 non-null   float64
#  1   exp_idx  4740 non-null   int64
#  2   epoch    4740 non-null   int64
#  3   mb_idx   4740 non-null   int64
#  4   mb_pass  4740 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 185.3 KB

# %%
loss_list = df['loss'].to_list()
print(loss_list)
# Out:
# [0.0002225643256679, 0.0007359886076301, -0.0018581405747681, -0.0025085292290896, -0.003084325697273, -0.0064282668754458, 0.0023174472153186, 0.0026207962073385, -0.0024212417192757, -0.00081443664385, 0.0001568992156535, -0.0046010268852114, -0.0024208822287619, -0.0014656170969828, -0.0029920551460236, -0.0057269581593573, -0.0008706593653187, -0.0081893876194953, -0.0061160586774349, 0.0003698383225128, -0.0112108895555138, -0.0057800435461103, -0.0069718435406684, -0.0133748240768909, 0.000792825478129, -0.0074234688654541, -0.0134082213044166, -0.0029820480849593, -0.0097565874457359, -0.0056340978480875, -0.0064843860454857, -0.0228646658360958, -0.0181009545922279, -0.0150314234197139, -0.0211527086794376, -0.0176515467464923, -0.0249684154987335, -0.0056865504011511, -0.0252127088606357, -0.0026911185123026, -0.0287136100232601, -0.0137236677110195, -0.017182745039463, -0.0126133989542722, -0.0041063707321882, -0.0317724496126174, -0.0231934376060962, -0.0309735722839832, -
# ...

# %%
plt.plot(loss_list)
plt.show()

# %%
for i, el in enumerate(loss_list):
    if el == 'loss':
        print(i)
