# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/no_strategy_byol_cifar100_11-12_14-45/pretr_loss.csv')
df.head()
# Out:
#        loss  exp_idx  epoch  mb_idx  mb_pass
# 0  4.005147        0      0       0        0
# 1  4.001071        0      0       0        1
# 2  4.021672        0      0       0        2
# 3  4.015386        0      0       1        0
# 4  4.007240        0      0       1        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4740 entries, 0 to 4739
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   loss     4740 non-null   float64
#  1   exp_idx  4740 non-null   int64
#  2   epoch    4740 non-null   int64
#  3   mb_idx   4740 non-null   int64
#  4   mb_pass  4740 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 185.3 KB

# %%
loss_list = df['loss'].to_list()
print(loss_list)
# Out:
# [4.005146503448486, 4.001071453094482, 4.021672248840332, 4.015385627746582, 4.007239818572998, 3.990581512451172, 4.01036548614502, 4.002630233764648, 3.970700979232788, 3.995638847351074, 3.965456962585449, 3.984239101409912, 3.956094264984131, 3.9513092041015625, 3.9554853439331055, 3.9916858673095694, 3.9608235359191895, 3.9979891777038574, 3.953205347061157, 3.936574459075928, 3.953402757644653, 3.977259159088135, 3.934080123901367, 3.91991138458252, 3.98336410522461, 3.876051425933838, 3.852631092071533, 3.884669065475464, 3.870008945465088, 3.901520729064941, 3.96169376373291, 3.865255355834961, 3.8791887760162354, 3.8672828674316406, 3.842077016830444, 3.878095865249634, 3.8507800102233887, 3.928445339202881, 3.917461395263672, 3.861244440078736, 3.819583177566528, 3.902582883834839, 3.8862264156341553, 3.8778891563415527, 3.938257932662964, 3.8217694759368896, 3.908508777618408, 3.872491836547852, 3.933740615844727, 3.8282296657562256, 3.865758657455444, 3.803952217102051, 3
# ...

# %%
plt.plot(loss_list)
plt.show()

# %%
for i, el in enumerate(loss_list):
    if el == 'loss':
        print(i)
