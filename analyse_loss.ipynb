# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/hypertune_no_strategy_simsiam_11-21_03-02/no_strategy_simsiam_cifar100_11-21_03-02/pretr_loss.csv')
df.head()
# Out:
#        loss  exp_idx  epoch  mb_idx  mb_pass
# 0  0.001918        0      0       0        0
# 1  0.004665        0      0       0        1
# 2  0.003725        0      0       0        2
# 3  0.004087        0      0       1        0
# 4  0.007423        0      0       1        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4740 entries, 0 to 4739
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   loss     4740 non-null   float64
#  1   exp_idx  4740 non-null   int64
#  2   epoch    4740 non-null   int64
#  3   mb_idx   4740 non-null   int64
#  4   mb_pass  4740 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 185.3 KB

# %%
loss_list = df['loss'].to_list()
print(loss_list)
# Out:
# [0.0019181036623194, 0.0046646557748317, 0.003724749200046, 0.0040869619697332, 0.0074227885343134, 0.0022297273389995, -0.0022341492585837, 0.0052159456536173, 0.0029785039369016, -0.0019743205048143, 0.0037049083039164, 0.0019424757920205, 0.0003112636040896, -0.0041087875142693, 0.0003584253136068, -0.002268620301038, -0.0052792821079492, -0.0014839218929409, -0.0036460754927247, -0.0022361683659255, -0.0032649391796439, -0.0057525020092725, -0.0027685216628015, -0.0053604273125529, -0.0039472291246056, -0.0010651865741237, 0.0016063989605754, -0.0069863302633166, -0.0078721037134528, -0.0007867626845836, -0.002472715685144, -0.0060271229594945, -0.004651659168303, -0.0068152733147144, -0.0004315651895012, -0.0122939189895987, -0.0142770064994692, -0.0042619034647941, -0.0051016402430832, -0.0115062873810529, 0.001392824226059, -0.0029639934655278, -0.0311339814215898, -0.0245729871094226, -0.0051336726173758, -0.0135812982916831, -0.0031224298290908, -0.0179316475987434, -0.00833
# ...

# %%
plt.plot(loss_list)
plt.show()

# %%
for i, el in enumerate(loss_list):
    if el == 'loss':
        print(i)
