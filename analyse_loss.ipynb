# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/replay_simsiam_cifar100_10-22_16-42/pretr_loss.csv')
df.head()
# Out:
#        loss   exp_idx   epoch   mb_idx   mb_pass
# 0  0.004420         0       0        0         0
# 1 -0.002341         0       0        0         1
# 2 -0.003264         0       0        0         2
# 3 -0.001815         0       0        0         3
# 4 -0.003740         0       0        0         4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7900 entries, 0 to 7899
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   loss      7900 non-null   float64
#  1    exp_idx  7900 non-null   int64
#  2    epoch    7900 non-null   int64
#  3    mb_idx   7900 non-null   int64
#  4    mb_pass  7900 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 308.7 KB

# %%
loss_list = df['loss'].to_list()
print(loss_list)
# Out:
# [0.0044197281822562, -0.0023405202664434, -0.0032643130980432, -0.0018153114942833, -0.0037399579305201, -0.003196810837835, -0.0014402577653527, -0.0083459261804819, -0.0043702889233827, -0.0114156901836395, -0.0127403382211923, -0.0088496971875429, -0.0060011516325175, -0.0031272256746888, -0.0105112120509147, -0.0151971261948347, -0.0168393179774284, -0.0157564654946327, -0.0049837492406368, -0.002924715867266, -0.0206531397998332, -0.006616513710469, -0.0056530013680458, -0.0121511565521359, -0.011379200965166, -0.0233868844807147, -0.0362838320434093, -0.0326135084033012, -0.0434711873531341, -0.0106675904244184, -0.0164954587817192, -0.0197154060006141, -0.0245257094502449, -0.0341231524944305, -0.010768374428153, -0.0258857607841491, -0.0113691641017794, -0.0074245957657694, -0.0199165139347314, -0.0258292481303215, -0.0126600014045834, -0.0105447666719555, -0.0181354358792305, -0.032561644911766, -0.0508046187460422, -0.0092531349509954, -0.0127515951171517, -0.04769765958189
# ...

# %%
plt.plot(loss_list)
plt.show()

# %%
for i, el in enumerate(loss_list):
    if el == 'loss':
        print(i)
