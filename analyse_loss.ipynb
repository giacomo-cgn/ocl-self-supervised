# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/replay_simsiam_cifar100_10-20_00-10/pretr_loss.csv')
df.head()
# Out:
#        loss   exp_idx   epoch   mb_idx   mb_pass
# 0  0.002293         0       0        0         0
# 1  0.001945         0       0        0         1
# 2 -0.002216         0       0        0         2
# 3 -0.005708         0       0        0         3
# 4 -0.006589         0       0        0         4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7900 entries, 0 to 7899
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   loss      7900 non-null   float64
#  1    exp_idx  7900 non-null   int64
#  2    epoch    7900 non-null   int64
#  3    mb_idx   7900 non-null   int64
#  4    mb_pass  7900 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 308.7 KB

# %%
loss_list = df['loss']

# %%
plt.plot(loss_list)
plt.show()
