# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('logs/replay_simsiam_cifar100_10-23_17-31/pretr_loss.csv')
df.head()
# Out:
#        loss  exp_idx  epoch  mb_idx  mb_pass
# 0 -0.005135        0      0       0        0
# 1 -0.004360        0      0       0        1
# 2 -0.003677        0      0       0        2
# 3 -0.003493        0      0       0        3
# 4 -0.003261        0      0       0        4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7900 entries, 0 to 7899
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   loss     7900 non-null   float64
#  1   exp_idx  7900 non-null   int64
#  2   epoch    7900 non-null   int64
#  3   mb_idx   7900 non-null   int64
#  4   mb_pass  7900 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 308.7 KB

# %%
loss_list = df['loss'].to_list()
print(loss_list)
# Out:
# [-0.0051347156986594, -0.0043598487973213, -0.0036772850435227, -0.0034927241504192, -0.0032605386804789, -0.001714215031825, 0.0011583439772948, -0.0076409010216593, -0.0019379226723685, -0.0048798425123095, -0.0041762311011552, 0.0017540876287966, -0.0042529217898845, -0.0045209806412458, -0.0003669201978482, -0.0070237442851066, -0.0081586688756942, -0.0048773875460028, -0.0069271996617317, -0.006688205525279, -0.0057790363207459, -0.0013591821771115, -0.008417117409408, -0.0092878136783838, -0.0026905168779194, -0.0155773656442761, -0.0106465090066194, -0.0104787219315767, -0.0075334953144192, -0.0018996914150193, -0.0041243326850235, -0.0132682835683226, -0.0054699727334082, -0.0036924658343195, -0.0124920075759291, -0.0033395690843462, -0.0026753679849207, -0.0168520100414752, -0.0031296522356569, -0.0192467905580997, -0.0169761404395103, -0.0164962373673915, -0.0016157259233295, -0.0061844340525567, -0.0070766783319413, -0.0021718125790357, -0.0101150386035442, -0.004782876931
# ...

# %%
plt.plot(loss_list)
plt.show()

# %%
for i, el in enumerate(loss_list):
    if el == 'loss':
        print(i)
